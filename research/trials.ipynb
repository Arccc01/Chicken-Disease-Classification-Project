# %%
dict = {"key": "value","key2": "value2"}

# %%
dict["key"]
# Out:
# 'value'

# %%
dict.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dict.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
# use of configbox
# ConfigBox provides attribute-style access to data stored in dictionaries or configuration files (like YAML)
from box import ConfigBox

# %%
d2 = ConfigBox(dict)

# %%
d2.key
# Out:
# 'value'

# %%
def product(a:int,b:int) ->int:
    return a*b

# %%
product(2,'3')
# Out:
# '33'

# %%
# it take care of type checking at runtime   
from ensure import ensure_annotations

# %%
@ensure_annotations
def product(a:int,b:int) ->int:
    return a*b

product(2,'3')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[19], line 5
#       1 @ensure_annotations
#       2 def product(a:int,b:int) ->int:
#       3     return a*b
# ----> 5 product(2,'3')
#
# File c:\Users\anujs\Documents\Chicken-Disease-Classification-Project\classy\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument b of type <class 'str'> to <function product at 0x000001A555AFFC40> does not match annotation type <class 'int'>
